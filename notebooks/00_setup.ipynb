# %% [markdown]
# # Project root

# %%
PROJ_ROOT <- Sys.getenv("SCRNA_PROJ_ROOT",
                        unname(Sys.getenv("PWD")))
data_dir    <- file.path(PROJ_ROOT, "data")
raw_dir     <- file.path(data_dir, "raw")
proc_dir    <- file.path(data_dir, "processed")
results_dir <- file.path(PROJ_ROOT, "results")
dir.create(proc_dir, showWarnings = FALSE, recursive = TRUE)
dir.create(file.path(results_dir, "figures"), showWarnings = FALSE, recursive = TRUE)
dir.create(file.path(results_dir, "tables"),  showWarnings = FALSE, recursive = TRUE)
set.seed(42)  # FindClusters/Harmony
